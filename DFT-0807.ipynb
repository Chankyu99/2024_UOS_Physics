# %%
import matplotlib.pyplot as plt
import numpy as np

file_path = 'bands.dat.gnu'
data = np.loadtxt(file_path)

k_points = data[:, 0]
energies = data[:, 1]

plt.plot(k_points, energies, marker = 'o')
plt.xlabel('k-points')
plt.ylabel('Energy (eV)')
plt.title('Band Structure')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('bands.dat.gnu')
dos = np.loadtxt('pdos.dat.pdos_tot')

k = np.unique(data[:, 0])
bands = np.reshape(data[:, 1], (-1, len(k)))
plt.figure(figsize=(9,4))
plt.subplot(121)
for band in range(len(bands)):
    plt.plot(k, bands[band, :], linewidth=1, alpha=0.5, color='k')
plt.xlim(min(k), max(k))

# Fermi energy
plt.axhline(0.921, linestyle=(0, (8, 10)), linewidth=0.75, color='k', alpha=0.5)
# High symmetry k-points (check bands_pp.out)
plt.axvline(0.6667, linewidth=0.75, color='k', alpha=0.5)
plt.axvline(1, linewidth=0.75, color='k', alpha=0.5)
# text labels
plt.xticks(ticks= [0, 0.6667, 1, 1.5774], labels=['$\Gamma$', 'K', 'M', '$\Gamma$'])
# plt.ylim(-1,1)
plt.ylabel("Energy (eV)")
plt.tight_layout()
plt.subplot(122)
plt.plot(dos[:,1],dos[:,0])
plt.ylim(-1,1)
plt.xlim(-0.1,4.5)
plt.ylabel('Energy')
plt.xlabel("DOS")
plt.tight_layout()
plt.show()

# %%
dos = np.loadtxt('./pdos.dat.pdos_tot')
plt.plot(dos[:,1],dos[:,0])

# %%
import matplotlib.pyplot as plt
import numpy as np

file_path = 'bn_bands.dat.gnu'
data = np.loadtxt(file_path)

k_points = data[:, 0]
energies = data[:, 1]

plt.plot(k_points, energies, marker = 'o')
plt.xlabel('k-points')
plt.ylabel('Energy (eV)')
plt.title('Band Structure')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('bn_bands.dat.gnu')
dos = np.loadtxt('bn_pdos.dat.pdos_tot')

k = np.unique(data[:, 0])
bands = np.reshape(data[:, 1], (-1, len(k)))
plt.figure(figsize=(9,4))
plt.subplot(121)
for band in range(len(bands)):
    plt.plot(k, bands[band, :], linewidth=1, alpha=0.5, color='k')
plt.xlim(min(k), max(k))

# Fermi energy
plt.axhline(0.921, linestyle=(0, (8, 10)), linewidth=0.75, color='k', alpha=0.5)
# High symmetry k-points (check bands_pp.out)
plt.axvline(0.6667, linewidth=0.75, color='k', alpha=0.5)
plt.axvline(1, linewidth=0.75, color='k', alpha=0.5)
# text labels
plt.xticks(ticks= [0, 0.6667, 1, 1.5774], labels=['$\Gamma$', 'M', 'K', '$\Gamma$'])
plt.ylim(-1,1)
plt.ylabel("Energy (eV)")
plt.subplot(122)
plt.plot(dos[:,1],dos[:,0])
plt.ylim(-1,1)
plt.xlim(-0.1,4.5)
plt.ylabel('DOS')
plt.xlabel("Energy (eV)")
plt.show()

# %%
# 8/8 피드백 받고 다시 한거
import matplotlib.pyplot as plt
import numpy as np

file_path = 'bands.dat.gnu'
data = np.loadtxt(file_path)

k_points = data[:, 0]
energies = data[:, 1]

plt.plot(k_points, energies, marker = 'o')
plt.xlabel('k-points')
plt.ylabel('Energy (eV)')
plt.title('Band Structure')
plt.grid(True)
plt.show()

# %%
# 8/8 피드백 받고 다시 한거 두번째
import matplotlib.pyplot as plt
import numpy as np

file_path = 'bands.dat.gnu'
data = np.loadtxt(file_path)

k_points = data[:, 0]
energies = data[:, 1]

plt.plot(k_points, energies, marker = 'o')
plt.xlabel('k-points')
plt.ylabel('Energy (eV)')
plt.title('Band Structure')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('bands.dat.gnu')
dos = np.loadtxt('graphene.pdos_tot')

k = np.unique(data[:, 0])
bands = np.reshape(data[:, 1], (-1, len(k)))
plt.figure(figsize=(9,4))
plt.subplot(121)
for band in range(len(bands)):
    plt.plot(k, bands[band, :], linewidth=1, alpha=0.5, color='k')
plt.xlim(min(k), max(k))

# Fermi energy
plt.axhline(0.921, linestyle=(0, (8, 10)), linewidth=0.75, color='k', alpha=0.5)
# High symmetry k-points (check bands_pp.out)
plt.axvline(0.6667, linewidth=0.75, color='k', alpha=0.5)
plt.axvline(1, linewidth=0.75, color='k', alpha=0.5)
# text labels
plt.xticks(ticks= [0, 0.6667, 1, 1.5774], labels=['$\Gamma$', 'K', 'M', '$\Gamma$'])
plt.ylim(-1,1)
plt.ylabel("Energy (eV)")
plt.tight_layout()
plt.subplot(122)
plt.plot(dos[:,1],dos[:,0])
plt.ylim(-1,1)
plt.xlim(-0.1,4.5)
plt.ylabel('Energy')
plt.xlabel("DOS")
plt.tight_layout()
plt.show()

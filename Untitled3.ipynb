# %%
import matplotlib.pyplot as plt
import numpy as np

# 파일 경로
file_path = 'bands.dat.gnu'

# 파일 읽기
data = np.loadtxt(file_path)

# k-점과 에너지 값 추출
k_points = data[:, 0]
energies = data[:, 1]

# 플롯팅
plt.figure(figsize=(8, 6))
plt.plot(k_points, energies, linestyle='-')
plt.xlabel('k-point')
plt.ylabel('Energy (eV)')
plt.title('Band Structure')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 파일 경로
file_path = 'a1_bands.dat.gnu'

# 파일 읽기
data = np.loadtxt(file_path)

# k-점과 에너지 값 추출
k_points = data[:, 0]
energies = data[:, 1]

# 플롯팅
plt.figure(figsize=(8, 6))
plt.plot(k_points, energies, linestyle='-')
plt.xlabel('k-point')
plt.ylabel('Energy (eV)')
plt.title('Band Structure')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 파일 경로
file_path = 'a2_bands.dat.gnu'

# 파일 읽기
data = np.loadtxt(file_path)

# k-점과 에너지 값 추출
k_points = data[:, 0]
energies = data[:, 1]

# 플롯팅
plt.figure(figsize=(8, 6))
plt.plot(k_points, energies, linestyle='-')
plt.xlabel('k-point')
plt.ylabel('Energy (eV)')
plt.title('Band Structure')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 파일 경로
file_path = 'a3_bands.dat.gnu'

# 파일 읽기
data = np.loadtxt(file_path)

# k-점과 에너지 값 추출
k_points = data[:, 0]
energies = data[:, 1]

# 플롯팅
plt.figure(figsize=(8, 6))
plt.plot(k_points, energies, linestyle='-')
plt.xlabel('k-point')
plt.ylabel('Energy (eV)')
plt.title('Band Structure')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 파일 경로
file_path = 'a4_bands.dat.gnu'

# 파일 읽기
data = np.loadtxt(file_path)

# k-점과 에너지 값 추출
k_points = data[:, 0]
energies = data[:, 1]

# 플롯팅
plt.figure(figsize=(8, 6))
plt.plot(k_points, energies, linestyle='-')
plt.xlabel('k-point')
plt.ylabel('Energy (eV)')
plt.title('Band Structure')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('a1_bands.dat.gnu')
dos = np.loadtxt('graphene_a1.pdos_tot')

k = np.unique(data[:, 0])
bands = np.reshape(data[:, 1], (-1, len(k)))
plt.figure(figsize=(9,4))
plt.subplot(121)
for band in range(len(bands)):
    plt.plot(k, bands[band, :], linewidth=1, alpha=0.5, color='k')
plt.xlim(min(k), max(k))

# Fermi energy
plt.axhline(0.921, linestyle=(0, (8, 10)), linewidth=0.75, color='k', alpha=0.5)
# High symmetry k-points (check bands_pp.out)
plt.axvline(0.6667, linewidth=0.75, color='k', alpha=0.5)
plt.axvline(1, linewidth=0.75, color='k', alpha=0.5)
# text labels
plt.xticks(ticks= [0, 0.6667, 1, 1.5774], labels=['$\Gamma$', 'K', 'M', '$\Gamma$'])
plt.ylim(-1,1)
plt.ylabel("Energy (eV)")
plt.subplot(122)
plt.plot(dos[:,1],dos[:,0])
plt.ylim(-1,1)
# plt.xlim(-0.1,4.5)
plt.ylabel('DOS')
plt.xlabel("Energy (eV)")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('a2_bands.dat.gnu')
dos = np.loadtxt('a2_graphene_a1.pdos_tot')

k = np.unique(data[:, 0])
bands = np.reshape(data[:, 1], (-1, len(k)))
plt.figure(figsize=(9,4))
plt.subplot(121)
for band in range(len(bands)):
    plt.plot(k, bands[band, :], linewidth=1, alpha=0.5, color='k')
plt.xlim(min(k), max(k))

# Fermi energy
plt.axhline(0.921, linestyle=(0, (8, 10)), linewidth=0.75, color='k', alpha=0.5)
# High symmetry k-points (check bands_pp.out)
plt.axvline(0.6667, linewidth=0.75, color='k', alpha=0.5)
plt.axvline(1, linewidth=0.75, color='k', alpha=0.5)
# text labels
plt.xticks(ticks= [0, 0.6667, 1, 1.5774], labels=['$\Gamma$', 'K', 'M', '$\Gamma$'])
plt.ylim(-1,1)
plt.ylabel("Energy (eV)")
plt.subplot(122)
plt.plot(dos[:,1],dos[:,0])
plt.ylim(-1,1)
# plt.xlim(-0.1,4.5)
plt.ylabel('DOS')
plt.xlabel("Energy (eV)")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('a3_bands.dat.gnu')
dos = np.loadtxt('a3_graphene_a1.pdos_tot')

k = np.unique(data[:, 0])
bands = np.reshape(data[:, 1], (-1, len(k)))
plt.figure(figsize=(9,4))
plt.subplot(121)
for band in range(len(bands)):
    plt.plot(k, bands[band, :], linewidth=1, alpha=0.5, color='k')
plt.xlim(min(k), max(k))

# Fermi energy
plt.axhline(0.921, linestyle=(0, (8, 10)), linewidth=0.75, color='k', alpha=0.5)
# High symmetry k-points (check bands_pp.out)
plt.axvline(0.6667, linewidth=0.75, color='k', alpha=0.5)
plt.axvline(1, linewidth=0.75, color='k', alpha=0.5)
# text labels
plt.xticks(ticks= [0, 0.6667, 1, 1.5774], labels=['$\Gamma$', 'K', 'M', '$\Gamma$'])
plt.ylim(-1,1)
plt.ylabel("Energy (eV)")
plt.subplot(122)
plt.plot(dos[:,1],dos[:,0])
plt.ylim(-1,1)
# plt.xlim(-0.1,4.5)
plt.ylabel('DOS')
plt.xlabel("Energy (eV)")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('a4_bands.dat.gnu')
dos = np.loadtxt('a44_graphene_a1.pdos_tot')

k = np.unique(data[:, 0])
bands = np.reshape(data[:, 1], (-1, len(k)))
plt.figure(figsize=(9,4))
plt.subplot(121)
for band in range(len(bands)):
    plt.plot(k, bands[band, :], linewidth=1, alpha=0.5, color='k')
plt.xlim(min(k), max(k))

# Fermi energy
plt.axhline(0.921, linestyle=(0, (8, 10)), linewidth=0.75, color='k', alpha=0.5)
# High symmetry k-points (check bands_pp.out)
plt.axvline(0.6667, linewidth=0.75, color='k', alpha=0.5)
plt.axvline(1, linewidth=0.75, color='k', alpha=0.5)
# text labels
plt.xticks(ticks= [0, 0.6667, 1, 1.5774], labels=['$\Gamma$', 'K', 'M', '$\Gamma$'])
plt.ylim(-1,1)
plt.ylabel("Energy (eV)")
plt.subplot(122)
plt.plot(dos[:,1],dos[:,0])
plt.ylim(-1,1)
# plt.xlim(-0.1,4.5)
plt.ylabel('DOS')
plt.xlabel("Energy (eV)")
plt.show()
